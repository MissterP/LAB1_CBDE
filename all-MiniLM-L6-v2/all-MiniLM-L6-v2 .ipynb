# %% [markdown]
# https://huggingface.co/datasets/williamkgao/bookcorpus100mb
# Podemos usar este data set porque solo son 100MB y tiene 1M de filas (> 10k)

# %%
# Instalamos los requisitos para trabajar con el modelo
# !pip install transformers datasets evaluate accelerate

# %%
# Usamos PyTorch enfrente de TensorFlow, pues el primero es más rápido, menos pesado, más fácil de aprender dando un prototipado rápido
# !pip install torch

# %%
from datasets import load_dataset

ds = load_dataset("williamkgao/bookcorpus100mb")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 1527753
#     })
# })

# %%
type(ds['train']['text'])
ds['train']['text']
# Out:
# ['usually , he would be tearing around the living room , playing with his toys .',
#  'but just one look at a minion sent him practically catatonic .',
#  "that had been megan 's plan when she got him dressed earlier .",
#  "he 'd seen the movie almost by mistake , considering he was a little young for the pg cartoon , but with older cousins , along with her brothers , mason was often exposed to things that were older .",
#  'she liked to think being surrounded by adults and older kids was one reason why he was a such a good talker for his age .',
#  "`` are n't you being a good boy ? ''",
#  'she said .',
#  'mason barely acknowledged her .',
#  'instead , his baby blues remained focused on the television .',
#  'since the movie was almost over , megan knew she better slip into the bedroom and finish getting ready .',
#  "each time she looked into mason 's face , she was grateful that he looked nothing like his father .",
# ...

# %%
len(ds['train']['text'])
# Out:
# 1527753

# %%
import random
#senteces = random.sample(ds['train']['text'], 10000)
senteces = ds['train']['text'][:10000]

# %%
len(senteces)
# Out:
# 10000

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#   Using cached transformers-4.45.1-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/199.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/199.4 MB 13.4 MB/s eta 0:00:15
#     --------------------------------------- 5.0/199.4 MB 12.1 MB/s eta 0:00:17
#    - -------------------------------------- 7.3/199.4 MB 12.2 MB/s eta 0:00:16
#    - -------------------------------------- 10.0/199.4 MB 11.9 MB/s eta 0:00:16
#    -- ------------------------------------- 12.3/199.4 MB 11.9 MB/s eta 0:00:16
#    -- ------------------------------------- 14.9/199.4 MB 11.9 MB/s eta 0:00:16
#    --- ------------------------------------ 17.6/199.4 MB 11.9 MB/s eta 0:00:16
#    ---- ----------------------------------- 20.2/199.4 MB 11.9 MB/s eta 0:00:16
#    ---- ----------------------------------- 22.5/199.4 MB 11.9 MB/s eta 0:00:15
# ...

# %%
# Facilita el uso del modelo con el que queremos trabajar
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
embeddings = model.encode(senteces)

# %%
print(embeddings)
# Out:
# [[ 0.06050314  0.03308406  0.04904869 ...  0.04487371 -0.00292978
#    0.07001354]
#  [ 0.08445659  0.05870396 -0.00918765 ...  0.07569066  0.00043239
#    0.06467737]
#  [-0.06773672  0.06862761  0.05655737 ... -0.07389869  0.0115964
#    0.00400647]
#  ...
#  [-0.00145     0.09431318 -0.0348192  ... -0.0502329   0.06953067
#   -0.00337821]
#  [ 0.0410806   0.12270593  0.04337889 ...  0.06757095  0.08922245
#   -0.00592208]
#  [ 0.02838586 -0.03320239  0.06891759 ... -0.03593131 -0.07754999
#    0.00294758]]
